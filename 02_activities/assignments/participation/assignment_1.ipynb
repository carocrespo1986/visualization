# %% [markdown]
# 2025/07/02 Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#generate dataset
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)
#generate plot
fig, ax = plt.subplots ( figsize=(5,3))

ax.scatter(x,y)

# %%
#generate dataset
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)
#generate plot
fig, ax = plt.subplots ( figsize=(5,3))

ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)

fig, ax = plt.subplots ( figsize=(5,3))

ax.barh(x,y) #horizontal bars
# Out:
# <BarContainer object of 50 artists>

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)

fig, ax = plt.subplots ( figsize=(5,3))

ax.plot(x,y) #conect dots

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)

fig, ax = plt.subplots ( figsize=(5,3))

ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots ( figsize=(5,3))
ax.plot(x,y)
#add titles and labels
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
# Out:
# Text(0.5, 0, 'Years since start')

# %%
#dictionaries for letter settings
font1 = {'family':'sans-serif', 'color':'blue', 'size':20}
font2 = {'family':'monospace', 'color':'green', 'size':14}

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

ax.set_title('Total growth over time', fontdict = font1)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter( x, y, 
            marker='*', 
            color = "indigo")

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot( x, y, 
            marker='*', 
            color = "indigo",
            linestyle = '--',
            linewidth = 2
            )

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot( x, y, 
            marker='*', 
            color = "#7425b9",
            linestyle = '--',
            linewidth = 2,
            markersize = 12,
            markeredgecolor = '#fa9359',
            markerfacecolor = '#000000' 
            )

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot( x, y, 
            marker='*', 
            color = "#7425b9",
            linestyle = '--',
            linewidth = 2,
            markersize = 12,
            markeredgecolor = '#fa9359',
            markerfacecolor = '#000000' 
            )
ax.grid(axis='y', 
        color="yellow",
        linestyle = "--"
        )

# %% [markdown]
# Chart from https://python-graph-gallery.com/

# %%
import seaborn as sns
import pandas as pd

# %%
#Data set:
a = pd.DataFrame({ 'group' : np.repeat('A',500), 'value': np.random.normal(10, 5, 500) }) 
    #500 samples, normal distribution (mean=10, std=5), labeled 'A'
b = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(13, 1.2, 500) }) 
    #500 samples, normal distribution (mean=13, std=1.2), labeled 'B'
c = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(18, 1.2, 500) }) 
    #500 samples, normal distribution (mean=18, std=1.2), also labeled 'B'
d = pd.DataFrame({ 'group' : np.repeat('C',20), 'value': np.random.normal(25, 4, 20) })
    #20 samples, normal distribution (mean=25, std=4), labeled 'C'
e = pd.DataFrame({ 'group' : np.repeat('D',100), 'value': np.random.uniform(12, size=100) })
    #100 samples, uniform distribution (between 0 and 12), labeled 'D'
df = pd.concat([a,b,c,d,e])

# %%
# only bloxplot
sns.boxplot(x='group', y='value', data=df)
# Out:
# <Axes: xlabel='group', ylabel='value'>

# %%
# only dots
ax = sns.stripplot(x='group', 
                   y='value', 
                   data=df, 
                   color="orange", 
                   jitter=0.2, 
                   size=2.5)

# add title
plt.title("Boxplot with jitter", loc="left")

# show the graph
plt.show()

# %%
sns.boxplot(x='group', y='value', data=df)

# add stripplot
ax = sns.stripplot(x='group', y='value', data=df, color="orange", jitter=0.2, size=2.5)

# add title
plt.title("Boxplot with jitter", loc="left")
# Out:
# Text(0.0, 1.0, 'Boxplot with jitter')

# %% [markdown]
# 2025/07/03 Visualization

# %%
#add comments
